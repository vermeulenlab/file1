# %%
# %%bash
# which pygenometracks
# Out:
# /Users/leandromoreno/anaconda3/bin/pygenometracks

# %%
# %run /Users/leandromoreno/anaconda3/bin/pygenometracks --tracks /Users/leandromoreno/Desktop/bigwig_track.ini.txt --region 2:85,122,763-85,143,799 -o /Users/leandromoreno/Desktop/bigwig.png
    
from IPython.display import Image
Image(filename = "/Users/leandromoreno/Desktop/bigwig.png")
# Out:
# INFO:pygenometracks.tracksClass:initialize 1. [test bigwig]
# INFO:pygenometracks.tracksClass:initialize 2. [test bigwig max]
# INFO:pygenometracks.tracksClass:initialize 3. [test bigwig]
# INFO:pygenometracks.tracksClass:initialize 4. [test bigwig max]
# INFO:pygenometracks.tracksClass:time initializing track(s):
# INFO:pygenometracks.tracksClass:0.015583038330078125
# DEBUG:pygenometracks.tracksClass:Figure size in cm is 40 x 6.382978723404256. Dpi is set to 72
#
# INFO:pygenometracks.tracksClass:plotting 1. [test bigwig]
# INFO:pygenometracks.tracksClass:plotting 2. [test bigwig max]
# INFO:pygenometracks.tracksClass:plotting 3. [test bigwig]
# INFO:pygenometracks.tracksClass:plotting 4. [test bigwig max]
